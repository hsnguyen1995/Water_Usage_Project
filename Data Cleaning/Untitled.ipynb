# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import json

La = "Resources/ladwp-water-supply-in-acre-feet.csv"
Cali = "Resources/cal_water_use.csv"

la_df = pd.read_csv(La)
Cali_df = pd.read_csv(Cali)

la_df.head()
# Out:
#    State Code  State Name  County Code     County Name  Year  \
# 0           6  California            1  Alameda County  1985
# 1           6  California            1  Alameda County  1990
# 2           6  California            1  Alameda County  1995
# 3           6  California            1  Alameda County  2000
# 4           6  California            1  Alameda County  2005
#
#    Total Population total population of area, in thousands  \
# 0                                           1195.160
# 1                                           1279.180
# 2                                           1347.700
# 3                                           1443.740
# 4                                           1448.905
#
#   Public Supply population served by groundwater, in thousands  \
# 0                                             185.95
# 1                                             109.37
# 2                                             165.83
# ...

# %%
Cali_df.head()
# Out:
#    State Code  State Name  County Code     County Name  Year  \
# 0           6  California            1  Alameda County  1985
# 1           6  California            1  Alameda County  1990
# 2           6  California            1  Alameda County  1995
# 3           6  California            1  Alameda County  2000
# 4           6  California            1  Alameda County  2005
#
#    Total Population total population of area, in thousands  \
# 0                                           1195.160
# 1                                           1279.180
# 2                                           1347.700
# 3                                           1443.740
# 4                                           1448.905
#
#   Public Supply population served by groundwater, in thousands  \
# 0                                             185.95
# 1                                             109.37
# 2                                             165.83
# ...

# %%
Recycle = len(la_df["Recycled Water"].unique())
Date = len(la_df["Date Value"].unique())
la_df = pd.DataFrame({"Recycled Water": [Recycle], "Date Value": [Date]})
la_df["Recycled"] = la_df["Recycled Water"].map("${:.2f}".format)

la_df.head()
# Out:
#    Recycled Water  Date Value Recycled
# 0               1           1    $1.00
