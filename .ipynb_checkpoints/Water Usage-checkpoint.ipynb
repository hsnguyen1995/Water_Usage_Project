# %%
import os
import pandas as pd
import csv
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from functools import reduce

file = "Resources/cleanest_data.csv"

water_df = pd.read_csv(file)

# %%
# Display dataset from csv
water_df
# Out:
#      Unnamed: 0            County  Year  Total Population in Thousands  \
# 0             0    Alameda County  1985                       1195.160
# 1             1    Alameda County  1990                       1279.180
# 2             2    Alameda County  1995                       1347.700
# 3             3    Alameda County  2000                       1443.740
# 4             4    Alameda County  2005                       1448.905
# 5             5    Alameda County  2010                       1510.271
# 6             6    Alameda County  2015                       1638.215
# 7             7     Alpine County  1985                          1.200
# 8             8     Alpine County  1990                          1.110
# 9             9     Alpine County  1995                          1.170
# 10           10     Alpine County  2000                          1.210
# 11           11     Alpine County  2005                          1.159
# 12           12     Alpine County  2010                          1.175
# 13           13     Alpine County  2015                          1.110
# 14           14     Amador County  1985                         22.890
# 15           15     Amador County  1990                         30.040
# 16           16     Amador County  1995                         32.600
# 17           17     Amador County  2000                         35.100
# 18           18     Amador County  2005                         38.471
# 19           19     Amador County  2010                         38.091
# 20           20     Amador County  2015                         37.001
# 21           21      Butte County  1985                        163.220
# 22           22      Butte County  1990                        182.120
# 23           23      Butte County  1995                        196.100
# 24           24      Butte County  2000                        203.170
# 25           25      Butte County  2005                        214.185
# 26           26      Butte County  2010                        220.000
# 27           27      Butte County  2015                        225.411
# 28           28  Calaveras County  1985                         26.880
# 29           29  Calaveras County  1990                         32.000
# ..          ...               ...   ...                            ...
# 376         376     Tulare County  2010                        442.179
# 377         377     Tulare County  2015                        459.863
# 378         378   Tuolumne County  1985                         40.470
# 379         379   Tuolumne County  1990                         48.460
# 380         380   Tuolumne County  1995                         51.500
# 381         381   Tuolumne County  2000                         54.500
# 382         382   Tuolumne County  2005                         59.380
# 383         383   Tuolumne County  2010                         55.365
# 384         384   Tuolumne County  2015                         53.709
# 385         385    Ventura County  1985                        599.770
# 386         386    Ventura County  1990                        669.020
# 387         387    Ventura County  1995                        712.700
# 388         388    Ventura County  2000                        753.200
# 389         389    Ventura County  2005                        796.106
# 390         390    Ventura County  2010                        823.318
# 391         391    Ventura County  2015                        850.536
# 392         392       Yolo County  1985                        124.350
# 393         393       Yolo County  1990                        141.090
# 394         394       Yolo County  1995                        150.800
# 395         395       Yolo County  2000                        168.660
# 396         396       Yolo County  2005                        184.932
# 397         397       Yolo County  2010                        200.849
# 398         398       Yolo County  2015                        213.016
# 399         399       Yuba County  1985                         53.970
# 400         400       Yuba County  1990                         58.230
# 401         401       Yuba County  1995                         62.300
# 402         402       Yuba County  2000                         60.220
# 403         403       Yuba County  2005                         67.153
# 404         404       Yuba County  2010                         72.155
# 405         405       Yuba County  2015                         74.492
#
#      Population Served in Thousands  \
# 0                          1153.110
# 1                          1251.810
# 2                          1328.650
# 3                          1266.880
# 4                          1433.494
# 5                          1448.700
# 6                          1629.900
# 7                             0.980
# 8                             0.600
# 9                             0.900
# 10                            0.600
# 11                            0.320
# 12                            0.750
# 13                            0.705
# 14                           12.540
# 15                           23.150
# 16                           26.700
# 17                           26.820
# 18                           20.225
# 19                           30.210
# 20                           27.920
# 21                          134.180
# 22                          122.720
# 23                          152.710
# 24                          164.770
# 25                          211.921
# 26                          186.200
# 27                          187.259
# 28                           20.710
# 29                           11.620
# ..                              ...
# 376                         374.940
# 377                         395.156
# 378                          37.750
# 379                          37.280
# 380                          40.630
# 381                          54.220
# 382                          54.613
# 383                          48.780
# 384                          51.073
# 385                         593.180
# 386                         549.050
# 387                         703.650
# 388                         736.970
# 389                         794.126
# 390                         771.980
# 391                         832.233
# 392                         122.420
# 393                         120.040
# 394                         129.890
# 395                         135.200
# 396                         165.171
# 397                         186.310
# 398                         191.998
# 399                          51.080
# 400                          36.200
# 401                          46.100
# 402                          39.330
# 403                          42.565
# 404                          60.690
# 405                          67.118
#
#      Public Self-Supply Withdrawals (Mgal/ day)  \
# 0                                           NaN
# 1                                           NaN
# 2                                        214.56
# 3                                           NaN
# 4                                        156.61
# 5                                        215.50
# 6                                        168.74
# 7                                           NaN
# 8                                           NaN
# 9                                          0.11
# 10                                          NaN
# 11                                         0.08
# 12                                         0.19
# 13                                         0.10
# 14                                          NaN
# 15                                          NaN
# 16                                         9.74
# 17                                          NaN
# 18                                         6.00
# 19                                         7.59
# 20                                         8.64
# 21                                          NaN
# 22                                          NaN
# 23                                        44.96
# 24                                          NaN
# 25                                        40.68
# 26                                        42.84
# 27                                        28.81
# 28                                          NaN
# 29                                          NaN
# ..                                          ...
# 376                                       79.16
# 377                                       70.33
# 378                                         NaN
# 379                                         NaN
# 380                                        5.73
# 381                                         NaN
# 382                                       13.85
# 383                                       16.69
# 384                                        5.47
# 385                                         NaN
# 386                                         NaN
# 387                                      147.44
# 388                                         NaN
# 389                                      126.68
# 390                                      163.30
# 391                                      130.02
# 392                                         NaN
# 393                                         NaN
# 394                                       38.66
# 395                                         NaN
# 396                                       21.27
# 397                                       39.56
# 398                                       26.91
# 399                                         NaN
# 400                                         NaN
# 401                                        8.59
# 402                                         NaN
# 403                                       14.21
# 404                                       10.53
# 405                                        8.95
#
#      Public Supply Per Capita (Gallons/Person/Day)  \
# 0                                              NaN
# 1                                              NaN
# 2                                            161.0
# 3                                              NaN
# 4                                            109.0
# 5                                            149.0
# 6                                            104.0
# 7                                              NaN
# 8                                              NaN
# 9                                            122.0
# 10                                             NaN
# 11                                           250.0
# 12                                           253.0
# 13                                           142.0
# 14                                             NaN
# 15                                             NaN
# 16                                           365.0
# 17                                             NaN
# 18                                           297.0
# 19                                           251.0
# 20                                           309.0
# 21                                             NaN
# 22                                             NaN
# 23                                           294.0
# 24                                             NaN
# 25                                           192.0
# 26                                           230.0
# 27                                           154.0
# 28                                             NaN
# 29                                             NaN
# ..                                             ...
# 376                                          211.0
# 377                                          178.0
# 378                                            NaN
# 379                                            NaN
# 380                                          141.0
# 381                                            NaN
# 382                                          254.0
# 383                                          342.0
# 384                                          107.0
# 385                                            NaN
# 386                                            NaN
# 387                                          210.0
# 388                                            NaN
# 389                                          160.0
# 390                                          212.0
# 391                                          156.0
# 392                                            NaN
# 393                                            NaN
# 394                                          298.0
# 395                                            NaN
# 396                                          129.0
# 397                                          212.0
# 398                                          140.0
# 399                                            NaN
# 400                                            NaN
# 401                                          186.0
# 402                                            NaN
# 403                                          334.0
# 404                                          174.0
# 405                                          133.0
#
#      Domestic Self-Supply Withdrawn (Mgal/day)  \
# 0                                         3.15
# 1                                         2.05
# 2                                         1.43
# 3                                        13.27
# 4                                         3.50
# 5                                         4.62
# 6                                         0.49
# 7                                         0.02
# 8                                         0.04
# 9                                         0.02
# 10                                        0.04
# 11                                        0.01
# 12                                        0.04
# 13                                        0.04
# 14                                        0.68
# 15                                        0.52
# 16                                        0.44
# 17                                        0.62
# 18                                        0.13
# 19                                        0.57
# 20                                        0.97
# 21                                        2.18
# 22                                        4.46
# 23                                        3.26
# 24                                        2.88
# 25                                        9.48
# 26                                        2.54
# 27                                        3.37
# 28                                        0.14
# 29                                        1.53
# ..                                         ...
# 376                                       5.04
# 377                                       7.16
# 378                                       0.21
# 379                                       0.84
# 380                                       0.81
# 381                                       0.02
# 382                                       4.09
# 383                                       0.19
# 384                                       0.18
# 385                                       0.49
# 386                                       9.00
# 387                                       0.68
# 388                                       0.92
# 389                                       1.34
# 390                                       3.63
# 391                                       1.75
# 392                                       0.14
# 393                                       1.58
# 394                                       1.57
# 395                                       2.51
# 396                                      12.20
# 397                                       1.08
# 398                                       1.69
# 399                                       0.22
# 400                                       1.65
# 401                                       1.21
# 402                                       1.57
# 403                                       3.56
# 404                                       0.86
# 405                                       0.70
#
#      Domestic Self-Supply Population (Thousands)  \
# 0                                         42.050
# 1                                         27.370
# 2                                         19.050
# 3                                        176.860
# 4                                         15.411
# 5                                         61.571
# 6                                          8.315
# 7                                          0.220
# 8                                          0.510
# 9                                          0.270
# 10                                         0.610
# 11                                         0.839
# 12                                         0.425
# 13                                         0.405
# 14                                        10.350
# 15                                         6.890
# 16                                         5.900
# 17                                         8.280
# 18                                        18.246
# 19                                         7.881
# 20                                         9.081
# 21                                        29.040
# 22                                        59.400
# 23                                        43.390
# 24                                        38.400
# 25                                         2.264
# 26                                        33.800
# 27                                        38.152
# 28                                         6.170
# 29                                        20.380
# ..                                           ...
# 376                                       67.239
# 377                                       64.707
# 378                                        2.720
# 379                                       11.180
# 380                                       10.870
# 381                                        0.280
# 382                                        4.767
# 383                                        6.585
# 384                                        2.636
# 385                                        6.590
# 386                                      119.970
# 387                                        9.050
# 388                                       16.230
# 389                                        1.980
# 390                                       51.338
# 391                                       18.303
# 392                                        1.930
# 393                                       21.050
# 394                                       20.910
# 395                                       33.460
# 396                                       19.761
# 397                                       14.539
# 398                                       21.018
# 399                                        2.890
# 400                                       22.030
# 401                                       16.200
# 402                                       20.890
# 403                                       24.588
# 404                                       11.465
# 405                                        7.374
#
#      Domestic total self-supplied withdrawals plus deliveries, in Mgal/d  \
# 0                                               122.16
# 1                                               143.44
# 2                                               143.45
# 3                                                  NaN
# 4                                                76.84
# 5                                               129.02
# 6                                                98.86
# 7                                                 0.12
# 8                                                 0.14
# 9                                                 0.12
# 10                                                 NaN
# 11                                                0.09
# 12                                                0.12
# 13                                                0.10
# 14                                                2.43
# 15                                                2.31
# 16                                                2.76
# 17                                                 NaN
# 18                                                4.94
# 19                                                3.69
# 20                                                3.96
# 21                                               26.36
# 22                                               25.28
# 23                                               33.88
# 24                                                 NaN
# 25                                               45.26
# 26                                               31.46
# 27                                               22.06
# 28                                                2.34
# 29                                                2.85
# ..                                                 ...
# 376                                              55.29
# 377                                              51.78
# 378                                               3.91
# 379                                               4.24
# 380                                               4.30
# 381                                                NaN
# 382                                              19.05
# 383                                               6.04
# 384                                               3.80
# 385                                              69.10
# 386                                             189.90
# 387                                              80.86
# 388                                                NaN
# 389                                              90.34
# 390                                              92.87
# 391                                              77.67
# 392                                              22.73
# 393                                              23.98
# 394                                              27.79
# 395                                                NaN
# 396                                              35.73
# 397                                              26.07
# 398                                              16.90
# 399                                               7.67
# 400                                               4.55
# 401                                               7.08
# 402                                                NaN
# 403                                              12.83
# 404                                               7.96
# 405                                               7.42
#
#      Domestic, Public-Supply, Gallons/Person/Day  \
# 0                                          103.0
# 1                                          113.0
# 2                                          107.0
# 3                                            NaN
# 4                                           51.0
# 5                                           86.0
# 6                                           60.0
# 7                                          102.0
# 8                                          167.0
# 9                                          111.0
# 10                                           NaN
# 11                                         250.0
# 12                                         107.0
# 13                                          85.0
# 14                                         140.0
# 15                                          77.0
# 16                                          87.0
# 17                                           NaN
# 18                                         238.0
# 19                                         103.0
# 20                                         107.0
# 21                                         180.0
# 22                                         170.0
# 23                                         201.0
# 24                                           NaN
# 25                                         169.0
# 26                                         155.0
# 27                                         100.0
# 28                                         106.0
# 29                                         114.0
# ..                                           ...
# 376                                        134.0
# 377                                        113.0
# 378                                         98.0
# 379                                         91.0
# 380                                         86.0
# 381                                          NaN
# 382                                        274.0
# 383                                        120.0
# 384                                         71.0
# 385                                        116.0
# 386                                        329.0
# 387                                        114.0
# 388                                          NaN
# 389                                        112.0
# 390                                        116.0
# 391                                         91.0
# 392                                        185.0
# 393                                        187.0
# 394                                        202.0
# 395                                          NaN
# 396                                        142.0
# 397                                        134.0
# 398                                         79.0
# 399                                        146.0
# 400                                         80.0
# 401                                        127.0
# 402                                          NaN
# 403                                        218.0
# 404                                        117.0
# 405                                        100.0
#
#      Total Domestic Consumption (Mgal/day)  \
# 0                                      NaN
# 1                                      NaN
# 2                                    37.30
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
# 9                                     0.04
# 10                                     NaN
# 11                                     NaN
# 12                                     NaN
# 13                                     NaN
# 14                                     NaN
# 15                                     NaN
# 16                                    0.72
# 17                                     NaN
# 18                                     NaN
# 19                                     NaN
# 20                                     NaN
# 21                                     NaN
# 22                                     NaN
# 23                                    8.81
# 24                                     NaN
# 25                                     NaN
# 26                                     NaN
# 27                                     NaN
# 28                                     NaN
# 29                                     NaN
# ..                                     ...
# 376                                    NaN
# 377                                    NaN
# 378                                    NaN
# 379                                    NaN
# 380                                   1.12
# 381                                    NaN
# 382                                    NaN
# 383                                    NaN
# 384                                    NaN
# 385                                    NaN
# 386                                    NaN
# 387                                  22.68
# 388                                    NaN
# 389                                    NaN
# 390                                    NaN
# 391                                    NaN
# 392                                    NaN
# 393                                    NaN
# 394                                   7.23
# 395                                    NaN
# 396                                    NaN
# 397                                    NaN
# 398                                    NaN
# 399                                    NaN
# 400                                    NaN
# 401                                   2.04
# 402                                    NaN
# 403                                    NaN
# 404                                    NaN
# 405                                    NaN
#
#      Domestic, Self-Supply, Gallons/Person/Day  \
# 0                                         75.0
# 1                                         75.0
# 2                                         75.0
# 3                                         75.0
# 4                                        227.0
# 5                                         75.0
# 6                                         59.0
# 7                                         91.0
# 8                                         78.0
# 9                                         74.0
# 10                                        66.0
# 11                                        12.0
# 12                                        94.0
# 13                                        99.0
# 14                                        66.0
# 15                                        75.0
# 16                                        75.0
# 17                                        75.0
# 18                                         7.0
# 19                                        72.0
# 20                                       107.0
# 21                                        75.0
# 22                                        75.0
# 23                                        75.0
# 24                                        75.0
# 25                                      4187.0
# 26                                        75.0
# 27                                        88.0
# 28                                        23.0
# 29                                        75.0
# ..                                         ...
# 376                                       75.0
# 377                                      111.0
# 378                                       77.0
# 379                                       75.0
# 380                                       75.0
# 381                                       71.0
# 382                                      858.0
# 383                                       29.0
# 384                                       68.0
# 385                                       74.0
# 386                                       75.0
# 387                                       75.0
# 388                                       57.0
# 389                                      677.0
# 390                                       71.0
# 391                                       96.0
# 392                                       73.0
# 393                                       75.0
# 394                                       75.0
# 395                                       75.0
# 396                                      617.0
# 397                                       74.0
# 398                                       80.0
# 399                                       76.0
# 400                                       75.0
# 401                                       75.0
# 402                                       75.0
# 403                                      145.0
# 404                                       75.0
# 405                                       95.0
#
#      Industrial, Self-Supply Withdrawn (Mgal/day)  \
# 0                                            3.88
# 1                                            0.00
# 2                                            6.75
# 3                                            2.96
# 4                                            0.05
# 5                                            0.90
# 6                                            0.90
# 7                                            0.00
# 8                                            0.00
# 9                                            0.00
# 10                                           0.00
# 11                                           0.04
# 12                                           0.00
# 13                                           0.00
# 14                                           0.00
# 15                                           0.00
# 16                                           0.00
# 17                                           0.15
# 18                                           0.10
# 19                                           0.41
# 20                                           0.41
# 21                                           1.65
# 22                                           0.00
# 23                                           0.00
# 24                                           0.26
# 25                                           1.27
# 26                                           4.02
# 27                                           4.02
# 28                                           0.59
# 29                                           0.00
# ..                                            ...
# 376                                         15.98
# 377                                         15.98
# 378                                          0.03
# 379                                          0.00
# 380                                          0.18
# 381                                          0.00
# 382                                          0.00
# 383                                          1.53
# 384                                          1.53
# 385                                          5.18
# 386                                          0.00
# 387                                          6.45
# 388                                          0.40
# 389                                          0.09
# 390                                         10.21
# 391                                         10.21
# 392                                          8.12
# 393                                          4.17
# 394                                          4.54
# 395                                          2.20
# 396                                          0.00
# 397                                          0.79
# 398                                          0.79
# 399                                          0.30
# 400                                          0.00
# 401                                          0.00
# 402                                          0.00
# 403                                          0.00
# 404                                          1.22
# 405                                          1.22
#
#      Industrial Total Consumption (Mgal/day)  \
# 0                                       2.53
# 1                                       2.55
# 2                                       8.29
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7                                       0.00
# 8                                       0.00
# 9                                       0.00
# 10                                       NaN
# 11                                       NaN
# 12                                       NaN
# 13                                       NaN
# 14                                      0.48
# 15                                      0.22
# 16                                      0.43
# 17                                       NaN
# 18                                       NaN
# 19                                       NaN
# 20                                       NaN
# 21                                      0.86
# 22                                      0.02
# 23                                      0.26
# 24                                       NaN
# 25                                       NaN
# 26                                       NaN
# 27                                       NaN
# 28                                      0.55
# 29                                      0.00
# ..                                       ...
# 376                                      NaN
# 377                                      NaN
# 378                                     0.42
# 379                                     0.00
# 380                                     0.05
# 381                                      NaN
# 382                                      NaN
# 383                                      NaN
# 384                                      NaN
# 385                                     5.50
# 386                                     1.20
# 387                                     4.24
# 388                                      NaN
# 389                                      NaN
# 390                                      NaN
# 391                                      NaN
# 392                                     2.04
# 393                                     1.40
# 394                                     1.33
# 395                                      NaN
# 396                                      NaN
# 397                                      NaN
# 398                                      NaN
# 399                                     0.22
# 400                                     0.00
# 401                                     0.04
# 402                                      NaN
# 403                                      NaN
# 404                                      NaN
# 405                                      NaN
#
#      Livestock, Self-Supply, Freshwater (Mgal/day)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                             0.88
# 4                                             0.32
# 5                                             0.27
# 6                                             0.27
# 7                                              NaN
# 8                                              NaN
# 9                                              NaN
# 10                                            0.07
# 11                                            0.03
# 12                                            0.01
# 13                                            0.00
# 14                                             NaN
# 15                                             NaN
# 16                                             NaN
# 17                                            0.62
# 18                                            0.32
# 19                                            0.23
# 20                                            0.23
# 21                                             NaN
# 22                                             NaN
# 23                                             NaN
# 24                                            0.61
# 25                                            0.42
# 26                                            0.32
# 27                                            0.29
# 28                                             NaN
# 29                                             NaN
# ..                                             ...
# 376                                          40.44
# 377                                          41.47
# 378                                            NaN
# 379                                            NaN
# 380                                            NaN
# 381                                           0.39
# 382                                           0.36
# 383                                           0.34
# 384                                           0.17
# 385                                            NaN
# 386                                            NaN
# 387                                            NaN
# 388                                           0.84
# 389                                           0.18
# 390                                           0.18
# 391                                           0.14
# 392                                            NaN
# 393                                            NaN
# 394                                            NaN
# 395                                           0.36
# 396                                           0.45
# 397                                           0.54
# 398                                           0.48
# 399                                            NaN
# 400                                            NaN
# 401                                            NaN
# 402                                           1.15
# 403                                           0.72
# 404                                           0.41
# 405                                           0.38
#
#      Livestock Consumption Freshwater (Mgal/day)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
# 6                                            NaN
# 7                                            NaN
# 8                                            NaN
# 9                                            NaN
# 10                                           NaN
# 11                                           NaN
# 12                                           NaN
# 13                                           NaN
# 14                                           NaN
# 15                                           NaN
# 16                                           NaN
# 17                                           NaN
# 18                                           NaN
# 19                                           NaN
# 20                                           NaN
# 21                                           NaN
# 22                                           NaN
# 23                                           NaN
# 24                                           NaN
# 25                                           NaN
# 26                                           NaN
# 27                                           NaN
# 28                                           NaN
# 29                                           NaN
# ..                                           ...
# 376                                          NaN
# 377                                          NaN
# 378                                          NaN
# 379                                          NaN
# 380                                          NaN
# 381                                          NaN
# 382                                          NaN
# 383                                          NaN
# 384                                          NaN
# 385                                          NaN
# 386                                          NaN
# 387                                          NaN
# 388                                          NaN
# 389                                          NaN
# 390                                          NaN
# 391                                          NaN
# 392                                          NaN
# 393                                          NaN
# 394                                          NaN
# 395                                          NaN
# 396                                          NaN
# 397                                          NaN
# 398                                          NaN
# 399                                          NaN
# 400                                          NaN
# 401                                          NaN
# 402                                          NaN
# 403                                          NaN
# 404                                          NaN
# 405                                          NaN
#
#      Irrigation, Crop, Self-Supply, Fresh (Mgal/day)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                              18.00
# 4                                                NaN
# 5                                              16.87
# 6                                               7.64
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 10                                             14.90
# 11                                               NaN
# 12                                              4.22
# 13                                              9.69
# 14                                               NaN
# 15                                               NaN
# 16                                               NaN
# 17                                             24.60
# 18                                               NaN
# 19                                             16.49
# 20                                             20.46
# 21                                               NaN
# 22                                               NaN
# 23                                               NaN
# 24                                            972.40
# 25                                               NaN
# 26                                            645.25
# 27                                            752.20
# 28                                               NaN
# 29                                               NaN
# ..                                               ...
# 376                                          2456.95
# 377                                          1394.94
# 378                                              NaN
# 379                                              NaN
# 380                                              NaN
# 381                                             4.40
# 382                                              NaN
# 383                                             4.45
# 384                                             2.78
# 385                                              NaN
# 386                                              NaN
# 387                                              NaN
# 388                                           225.60
# 389                                              NaN
# 390                                           216.89
# 391                                            79.97
# 392                                              NaN
# 393                                              NaN
# 394                                              NaN
# 395                                           981.20
# 396                                              NaN
# 397                                           736.72
# 398                                           571.24
# 399                                              NaN
# 400                                              NaN
# 401                                              NaN
# 402                                           357.70
# 403                                              NaN
# 404                                           240.07
# 405                                           314.19
#
#      Irrigation Crop Consumtion Freshwater (Mgal)
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# 5                                             NaN
# 6                                            6.55
# 7                                             NaN
# 8                                             NaN
# 9                                             NaN
# 10                                            NaN
# 11                                            NaN
# 12                                            NaN
# 13                                           6.99
# 14                                            NaN
# 15                                            NaN
# 16                                            NaN
# 17                                            NaN
# 18                                            NaN
# 19                                            NaN
# 20                                          16.96
# 21                                            NaN
# 22                                            NaN
# 23                                            NaN
# 24                                            NaN
# 25                                            NaN
# 26                                            NaN
# 27                                         591.51
# 28                                            NaN
# 29                                            NaN
# ..                                            ...
# 376                                           NaN
# 377                                       1085.73
# 378                                           NaN
# 379                                           NaN
# 380                                           NaN
# 381                                           NaN
# 382                                           NaN
# 383                                           NaN
# 384                                          2.02
# 385                                           NaN
# 386                                           NaN
# 387                                           NaN
# 388                                           NaN
# 389                                           NaN
# 390                                           NaN
# 391                                         66.16
# 392                                           NaN
# 393                                           NaN
# 394                                           NaN
# 395                                           NaN
# 396                                           NaN
# 397                                           NaN
# 398                                        431.42
# 399                                           NaN
# 400                                           NaN
# 401                                           NaN
# 402                                           NaN
# 403                                           NaN
# 404                                           NaN
# 405                                        240.19
#
# [406 rows x 19 columns]

# %%
# Count how many individual counties there are in the dataset
counties = water_df["County"].drop_duplicates()
counties.count()
# Out:
# 58

# %%
# Potentially useful dataframe which sets county name and year as index
summary_by_county = pd.DataFrame(water_df.groupby(["County","Year"]).sum()[["Domestic total self-supplied withdrawals plus deliveries, in Mgal/d",
                                                                  "Industrial, Self-Supply Withdrawn (Mgal/day)", 
                                                                  "Industrial Total Consumption (Mgal/day)",
                                                                   "Livestock, Self-Supply, Freshwater (Mgal/day)",
                                                                   "Livestock Consumption Freshwater (Mgal/day)",
                                                                   "Irrigation, Crop, Self-Supply, Fresh (Mgal/day)",
                                                                   "Irrigation Crop Consumtion Freshwater (Mgal)"]])

# Find total water use by adding all subcategories of use together
summary_by_county = pd.DataFrame(summary_by_county["Domestic total self-supplied withdrawals plus deliveries, in Mgal/d"] +
                                 summary_by_county["Industrial, Self-Supply Withdrawn (Mgal/day)"] +
                                 summary_by_county["Industrial Total Consumption (Mgal/day)"] +
                                 summary_by_county["Livestock, Self-Supply, Freshwater (Mgal/day)"] +
                                 summary_by_county["Livestock Consumption Freshwater (Mgal/day)"] +
                                 summary_by_county["Irrigation, Crop, Self-Supply, Fresh (Mgal/day)"] +
                                 summary_by_county["Irrigation Crop Consumtion Freshwater (Mgal)"],
                                columns = ['Total Water Use (Mgal/day)'])

summary_by_county.head()
# Out:
#                      Total Water Use (Mgal/day)
# County         Year
# Alameda County 1985                      128.57
#                1990                      145.99
#                1995                      158.49
#                2000                       21.84
#                2005                       77.21

# %%
# Find data for just Los Angeles County
LA_df = pd.DataFrame(water_df.loc[water_df["County"] == 'Los Angeles County',:])

LA_df.head()
# Out:
#      Unnamed: 0              County  Year  Total Population in Thousands  \
# 126         126  Los Angeles County  1985                       8105.540
# 127         127  Los Angeles County  1990                       8863.110
# 128         128  Los Angeles County  1995                       9352.200
# 129         129  Los Angeles County  2000                       9519.340
# 130         130  Los Angeles County  2005                       9935.475
#
#      Population Served in Thousands  \
# 126                        7724.760
# 127                        8422.120
# 128                        9313.860
# 129                        8509.220
# 130                        9076.276
#
#      Public Self-Supply Withdrawals (Mgal/ day)  \
# 126                                         NaN
# 127                                         NaN
# 128                                     1472.80
# 129                                         NaN
# 130                                     1859.63
#
#      Public Supply Per Capita (Gallons/Person/Day)  \
# 126                                            NaN
# 127                                            NaN
# 128                                          158.0
# 129                                            NaN
# 130                                          205.0
#
#      Domestic Self-Supply Withdrawn (Mgal/day)  \
# 126                                      24.96
# 127                                      30.27
# 128                                       2.88
# 129                                      75.76
# 130                                      19.10
#
#      Domestic Self-Supply Population (Thousands)  \
# 126                                      380.780
# 127                                      440.990
# 128                                       38.340
# 129                                     1010.120
# 130                                      859.199
#
#      Domestic total self-supplied withdrawals plus deliveries, in Mgal/d  \
# 126                                             956.19
# 127                                            1145.30
# 128                                            1061.26
# 129                                                NaN
# 130                                            1125.76
#
#      Domestic, Public-Supply, Gallons/Person/Day  \
# 126                                        121.0
# 127                                        132.0
# 128                                        114.0
# 129                                          NaN
# 130                                        122.0
#
#      Total Domestic Consumption (Mgal/day)  \
# 126                                    NaN
# 127                                    NaN
# 128                                 299.46
# 129                                    NaN
# 130                                    NaN
#
#      Domestic, Self-Supply, Gallons/Person/Day  \
# 126                                       66.0
# 127                                       69.0
# 128                                       75.0
# 129                                       75.0
# 130                                       22.0
#
#      Industrial, Self-Supply Withdrawn (Mgal/day)  \
# 126                                         98.60
# 127                                         34.05
# 128                                        167.29
# 129                                         57.73
# 130                                         11.67
#
#      Industrial Total Consumption (Mgal/day)  \
# 126                                    66.15
# 127                                    40.48
# 128                                    77.02
# 129                                      NaN
# 130                                      NaN
#
#      Livestock, Self-Supply, Freshwater (Mgal/day)  \
# 126                                            NaN
# 127                                            NaN
# 128                                            NaN
# 129                                           2.98
# 130                                           0.30
#
#      Livestock Consumption Freshwater (Mgal/day)  \
# 126                                          NaN
# 127                                          NaN
# 128                                          NaN
# 129                                          NaN
# 130                                          NaN
#
#      Irrigation, Crop, Self-Supply, Fresh (Mgal/day)  \
# 126                                              NaN
# 127                                              NaN
# 128                                              NaN
# 129                                             51.4
# 130                                              NaN
#
#      Irrigation Crop Consumtion Freshwater (Mgal)
# 126                                           NaN
# 127                                           NaN
# 128                                           NaN
# 129                                           NaN
# 130                                           NaN

# %%
LA_df = LA_df.rename(columns={"Domestic total self-supplied withdrawals plus deliveries, in Mgal/d": 
                              "Total LA County Residential Use (Mgal/day)"})

LA_df["Total LA County Agricultural Use (Mgal/day)"] = LA_df["Livestock, Self-Supply, Freshwater (Mgal/day)"] + LA_df["Livestock Consumption Freshwater (Mgal/day)"] + LA_df["Irrigation, Crop, Self-Supply, Fresh (Mgal/day)"] + LA_df["Irrigation Crop Consumtion Freshwater (Mgal)"]
            
LA_df["Total LA County Industrial Use (Mgal/day)"] = LA_df["Industrial, Self-Supply Withdrawn (Mgal/day)"] + LA_df["Industrial Total Consumption (Mgal/day)"]
    

LA_df = LA_df[["Year", "Total Population in Thousands", "Total LA County Residential Use (Mgal/day)", "Total LA County Industrial Use (Mgal/day)", "Total LA County Agricultural Use (Mgal/day)"]]

LA_df = LA_df.rename(columns={"Total Population in Thousands": 
                              "Total LA County Population in Thousands"})

LA_df.set_index('Year')
# Out:
#       Total LA County Population in Thousands  \
# Year
# 1985                                 8105.540
# 1990                                 8863.110
# 1995                                 9352.200
# 2000                                 9519.340
# 2005                                 9935.475
# 2010                                 9818.605
# 2015                                10170.292
#
#       Total LA County Residential Use (Mgal/day)  \
# Year
# 1985                                      956.19
# 1990                                     1145.30
# 1995                                     1061.26
# 2000                                         NaN
# 2005                                     1125.76
# 2010                                      968.13
# 2015                                      820.29
#
#       Total LA County Industrial Use (Mgal/day)  \
# Year
# 1985                                     164.75
# 1990                                      74.53
# 1995                                     244.31
# 2000                                        NaN
# 2005                                        NaN
# 2010                                        NaN
# 2015                                        NaN
#
#       Total LA County Agricultural Use (Mgal/day)
# Year
# 1985                                          NaN
# 1990                                          NaN
# 1995                                          NaN
# 2000                                          NaN
# 2005                                          NaN
# 2010                                          NaN
# 2015                                          NaN

# %%
populations = pd.DataFrame(water_df.groupby("Year").sum()["Population Served in Thousands"])
populations = populations.rename(columns = {"Population Served in Thousands" : "Population Served in CA (in Thousands)"})

populations
# Out:
#       Population Served in CA (in Thousands)
# Year
# 1985                               24345.860
# 1990                               25476.770
# 1995                               30466.290
# 2000                               30059.190
# 2005                               33424.931
# 2010                               34777.909
# 2015                               37709.308

# %%
industrial_summary = pd.DataFrame(water_df.groupby("Year").sum()[["Industrial, Self-Supply Withdrawn (Mgal/day)", 
                                                                  "Industrial Total Consumption (Mgal/day)"]])

industrial_total = pd.DataFrame(industrial_summary["Industrial, Self-Supply Withdrawn (Mgal/day)"] +
                                industrial_summary["Industrial Total Consumption (Mgal/day)"],
                                columns = ['Total Industrial Use in CA (Mgal/day)'])

industrial_total
# Out:
#       Total Industrial Use in CA (Mgal/day)
# Year
# 1985                                1005.56
# 1990                                 255.63
# 1995                                 822.74
# 2000                                 201.91
# 2005                                  95.67
# 2010                                 399.97
# 2015                                 398.55

# %%
agri_summary = pd.DataFrame(water_df.groupby("Year").sum()[["Livestock, Self-Supply, Freshwater (Mgal/day)",
                                                            "Livestock Consumption Freshwater (Mgal/day)",
                                                            "Irrigation, Crop, Self-Supply, Fresh (Mgal/day)",
                                                            "Irrigation Crop Consumtion Freshwater (Mgal)"]])

agri_total = pd.DataFrame(agri_summary["Livestock, Self-Supply, Freshwater (Mgal/day)"] + 
                                  agri_summary["Livestock Consumption Freshwater (Mgal/day)"]+
                                  agri_summary["Irrigation, Crop, Self-Supply, Fresh (Mgal/day)"] + 
                                  agri_summary["Irrigation Crop Consumtion Freshwater (Mgal)"], 
                                  columns = ['Total Agricultural Use in CA (Mgal/day)'])

agri_total
# Out:
#       Total Agricultural Use in CA (Mgal/day)
# Year
# 1985                                     0.00
# 1990                                     0.00
# 1995                                     0.00
# 2000                                 30756.15
# 2005                                   196.62
# 2010                                 23031.22
# 2015                                 33648.03

# %%
residential_total = pd.DataFrame(water_df.groupby("Year").sum()
                                 ["Domestic total self-supplied withdrawals plus deliveries, in Mgal/d"])

residential_total = residential_total.rename(columns = {"Domestic total self-supplied withdrawals plus deliveries, in Mgal/d" :
                                                        "Total Residential Use in CA (Mgal/day)"})

residential_total
# Out:
#       Total Residential Use in CA (Mgal/day)
# Year
# 1985                                 3378.87
# 1990                                 4058.13
# 1995                                 3830.97
# 2000                                    0.00
# 2005                                 4469.50
# 2010                                 4037.56
# 2015                                 3354.71

# %%
data_frames = [populations, residential_total, industrial_total, agri_total]
total_state_data = reduce(lambda  left,right: pd.merge(left,right,on=['Year'],
                                            how='outer'), data_frames)

total_state_data = total_state_data.replace(0.00, np.nan)
total_state_data
# Out:
#       Population Served in CA (in Thousands)  \
# Year
# 1985                               24345.860
# 1990                               25476.770
# 1995                               30466.290
# 2000                               30059.190
# 2005                               33424.931
# 2010                               34777.909
# 2015                               37709.308
#
#       Total Residential Use in CA (Mgal/day)  \
# Year
# 1985                                 3378.87
# 1990                                 4058.13
# 1995                                 3830.97
# 2000                                     NaN
# 2005                                 4469.50
# 2010                                 4037.56
# 2015                                 3354.71
#
#       Total Industrial Use in CA (Mgal/day)  \
# Year
# 1985                                1005.56
# 1990                                 255.63
# 1995                                 822.74
# 2000                                 201.91
# 2005                                  95.67
# 2010                                 399.97
# 2015                                 398.55
#
#       Total Agricultural Use in CA (Mgal/day)
# Year
# 1985                                      NaN
# 1990                                      NaN
# 1995                                      NaN
# 2000                                 30756.15
# 2005                                   196.62
# 2010                                 23031.22
# 2015                                 33648.03

# %%
LA_df
# Out:
#      Year  Total LA County Population in Thousands  \
# 126  1985                                 8105.540
# 127  1990                                 8863.110
# 128  1995                                 9352.200
# 129  2000                                 9519.340
# 130  2005                                 9935.475
# 131  2010                                 9818.605
# 132  2015                                10170.292
#
#      Total LA County Residential Use (Mgal/day)  \
# 126                                      956.19
# 127                                     1145.30
# 128                                     1061.26
# 129                                         NaN
# 130                                     1125.76
# 131                                      968.13
# 132                                      820.29
#
#      Total LA County Industrial Use (Mgal/day)  \
# 126                                     164.75
# 127                                      74.53
# 128                                     244.31
# 129                                        NaN
# 130                                        NaN
# 131                                        NaN
# 132                                        NaN
#
#      Total LA County Agricultural Use (Mgal/day)
# 126                                          NaN
# 127                                          NaN
# 128                                          NaN
# 129                                          NaN
# 130                                          NaN
# 131                                          NaN
# 132                                          NaN

# %%
comparison_df = pd.merge(total_state_data, LA_df, on = "Year", how = "outer")
comparison_df.set_index('Year')

comparison_df
# Out:
#    Year  Population Served in CA (in Thousands)  \
# 0  1985                               24345.860
# 1  1990                               25476.770
# 2  1995                               30466.290
# 3  2000                               30059.190
# 4  2005                               33424.931
# 5  2010                               34777.909
# 6  2015                               37709.308
#
#    Total Residential Use in CA (Mgal/day)  \
# 0                                 3378.87
# 1                                 4058.13
# 2                                 3830.97
# 3                                     NaN
# 4                                 4469.50
# 5                                 4037.56
# 6                                 3354.71
#
#    Total Industrial Use in CA (Mgal/day)  \
# 0                                1005.56
# 1                                 255.63
# 2                                 822.74
# 3                                 201.91
# 4                                  95.67
# 5                                 399.97
# 6                                 398.55
#
#    Total Agricultural Use in CA (Mgal/day)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                 30756.15
# 4                                   196.62
# 5                                 23031.22
# 6                                 33648.03
#
#    Total LA County Population in Thousands  \
# 0                                 8105.540
# 1                                 8863.110
# 2                                 9352.200
# 3                                 9519.340
# 4                                 9935.475
# 5                                 9818.605
# 6                                10170.292
#
#    Total LA County Residential Use (Mgal/day)  \
# 0                                      956.19
# 1                                     1145.30
# 2                                     1061.26
# 3                                         NaN
# 4                                     1125.76
# 5                                      968.13
# 6                                      820.29
#
#    Total LA County Industrial Use (Mgal/day)  \
# 0                                     164.75
# 1                                      74.53
# 2                                     244.31
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
#
#    Total LA County Agricultural Use (Mgal/day)
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# 5                                          NaN
# 6                                          NaN

# %%
# Compare residential usage per capita

LAC_per_cap = comparison_df["Total LA County Residential Use (Mgal/day)"]/comparison_df["Total LA County Population in Thousands"]*1000

CA_per_cap = comparison_df["Total Residential Use in CA (Mgal/day)"]/comparison_df["Population Served in CA (in Thousands)"]*1000

plt.figure(figsize = (10, 5))
barWidth = 0.25

x_axis = np.arange(len(comparison_df))
x_axis2 = [x + barWidth for x in x_axis]
tick_locations = [value + 0.2 for value in x_axis]

plt.bar(x_axis, LAC_per_cap, width=barWidth, alpha = 0.5, align="edge", color="r", label="LA County Use per Person")
plt.bar(x_axis+barWidth, CA_per_cap, width=barWidth, alpha = 0.5, align="edge", label="CA Use per Person")

plt.xlim(-0.5, len(x_axis))
plt.xticks(tick_locations, comparison_df["Year"])
plt.title("Water Use per Capita: LA County vs. California")
plt.xlabel("Year")
plt.ylabel("Water Consumption (Gallons/Person) ")
plt.legend()

plt.savefig("Images/LAC_vs_CA.png")
plt.show()

# %%
# Make a new dataframe which "Year" is set as index
comparison2_df = comparison_df.set_index("Year")

# Set plot size
plt.figure()

# Plot comparison2_df with the second column as the second y-axis
ax = comparison2_df.plot(secondary_y = ['Population Served in CA (in Thousands)'])

ax.set_ylabel('Water Use (Million Gallons per Day)')
ax.right_ax.set_ylabel('Population (Thousands)')

# Place legend outside of the plot
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.right_ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])

ax.legend(loc='center left', bbox_to_anchor=(1.25, 0.5))
ax.right_ax.legend(loc='center left', bbox_to_anchor=(1.25, .8))

# Name title of the plot and x-axis
plt.title ("State vs. Los Angeles County Total Water Usage by Type")
plt.xlabel("Year")

plt.savefig("Images/State_vs_Water.png", bbox_inches='tight')
plt.show()

# %%
ind = total_state_data.index 
width = 3      

plt.figure(figsize =(10,7))
p1 = plt.bar(ind, total_state_data["Total Residential Use in CA (Mgal/day)"], width)
p2 = plt.bar(ind, total_state_data["Total Industrial Use in CA (Mgal/day)"], width)
p3 = plt.bar(ind, total_state_data["Total Agricultural Use in CA (Mgal/day)"], width)


plt.ylabel("Year")
plt.xlabel("Water Use (Million Gallons per Day)")
plt.title("Total CA Water Usage by Service Type")
plt.legend((p1[0], p2[0],p3[0]), ('Residential', 'Industrial', 'Agricultural'), loc = 'upper left')

plt.savefig("Images/Water_Use_by_Service.png")
plt.show()
